# %%
import subprocess
import pandas as pd

# %%
# Executar o programa e capturar a saída
resultado = subprocess.run(["ordenacao\insertion\insertion.exe"], capture_output=True, text=True)

# Ver a saída bruta (debug)
print(resultado.stdout)
